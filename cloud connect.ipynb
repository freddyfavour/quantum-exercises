# %%
import qiskit
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
qiskit.__version__
# Out:
# '2.2.1'

# %%
service = QiskitRuntimeService()
backend = service.backend(name = "ibm_fez")
# Out:
# management.get:WARNING:2025-11-05 16:54:35,834: Loading default saved account

# %%
backend
# Out:
# 156

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

qc.draw(output='mpl')
